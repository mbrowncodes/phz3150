# %% [markdown]
# 1. A sentence with correct syntax but incorrect characters would be, "Th!s sent3nce is c0rrec+"
# A sentence with incorrect syntax but correct characters would be, "Sentence is correct this"
# Natural languages has some words that may have multiple different meanings, as well as too many filler gramatical words like "too, to, there, them" that would be hard to follow in code. Some more complex parts of natural language, like figurative language, would make it near impossible to run some function when its meaning may not be exactly as written.
# 2. Completed the GitHub Hello World tutorial, added my hw1 folder into my proper GitHub homework folder. Screenshotted changes in the GitHub Desktop before committing them. Screenshotted commited change of homework folder on the web GitHub in my account.
# 3. Opened a new Jupyter notebook, made a description markdown cell, created a code to with multiple variables and preformed basic algebraic functions upon it.

# %% [markdown]
# ![hw2_mbrown_ss1_GitHubDesktop.png](attachment:ac90fdb8-823b-45c2-97e5-ccbd421c3de3.png)
# ![hw2_mbrown_ss2_GitHubWeb.png](attachment:202f664c-6a82-4d86-ac45-f461dbfadda4.png)

# %% [markdown]
# This is my first practice notebook, opened during the 3rd week of the semster for the second assignment.

# %%
x = 10
y = 100
z = x*y
w = y-x
print("The product of x and y is",z,"and y minus x is",w,".")
# Out:
# The product of x and y is 1000 and y minus x is 90 .

# %%
min = 3 
#min is not a good name for a variable
#min lit up as a different color, showing it has a assigned function
#naming it min_1, or time_in_min is okay, but not just min
#this will only create problems later, if you wanted to call the function min
#it will take min as a variable, and it cant preform its original function

# %%
q = 1
print(q)
q += 1
print(q)
print(q * 10)
# Out:
# 1
# 2
# 20
