# %% [markdown]
# # Week 5. Plotting Basics

# %% [markdown]
# Matplotlib is the plotting module of Python. Matplotib is there to “make easy things easy and hard things possible” (https://matplotlib.org/). You can use it for making publication ready figures of any kind: histograms, plots, scatterplots, display images, etc.

# %% [markdown]
# ---
#
# ## Motivation
#
# Visualizing data is usually the best way to convey important engineering and science ideas and information, especially if the information is made up of many, many numbers. The ability to visualize and plot data quickly and in many different ways is one of Python's most powerful features.
#
# Python has numerous graphics functions that enable you to efficiently display plots, images, surfaces, volumes, vector fields, histograms, animations, and many other data plots. By the end of this chapter, you should be familiar with the most common ones and have enough information to explore the rest.
#
# ---

# %% [markdown]
# ## 2D Plotting

# %% [markdown]
# In Python, the *matplotlib* is the most important package that to make a plot, you can have a look of the [matplotlib gallery](https://matplotlib.org/gallery/index.html#gallery) and get a sense of what could be done there. Usually the first thing we need to do to make a plot is to import the matplotlib package. In Jupyter notebook, we could show the figure directly within the notebook and also have the interactive operations like pan, zoom in/out, and so on using the magic command - *%matplotlib notebook*. Let's see some examples.

# %%
import numpy as np
import matplotlib.pyplot as plt #if questions, look up stack overflow

# %% [markdown]
# The basic plotting function is *plot(x,y)*. The *plot* function takes in two lists/arrays, x and y, and produces a visual display of the respective points in x and y.
#
# **TRY IT!** Given the lists x = [0, 1, 2, 3] and y = [0, 1, 4, 9], use the plot function to produce a plot of x versus y.

# %%
x = [0, 1, 2, 3] 
y = [0, 1, 4, 9]
plt.figure(figsize=(10,3))
plt.xlabel("X axis", fontsize = 20)
plt.ylabel("Y axis", fontsize = 20)
plt.plot(x, y,label = "my blue line")  #need list/array for both x and y coordinates
plt.title("my blue plot", fontsize = 30)
plt.legend()
plt.show()
plt.savefig("myblueplot.png") #will save sepereate .png file in folder

# %% [markdown]
# You will notice in the above figure that by default, the plot function connects each point with a blue line. To make the function look smooth, use a finer discretization points. The *plt.plot* function did the main job to plot the figure, and *plt.show()* is telling Python that we are done plotting and please show the figure (you don't need to do this in Jupyter notebooks but you do in Ipython, etc.). Also, you can see some buttons beneath the plot that you could use it to move the line, zoom in or out, save the figure. Note that, before you plot the next figure, you need to turn off the interactive plot by pressing the *stop interaction* button on the top right of the figure. Otherwise, the next figure will be plotted in the same frame. Or we could simply using the magic function *%matplotlib inline* to turn off the interactive features.
#
# **TRY IT!** Make a plot of the function $f(x) = x^2 for -5\le x \le 5$.

# %%
x = np.linspace(-5,5, 100) #-5 to 5 with 100 evenly spaced points
plt.plot(x, x**2) #y = x squared
plt.show() #the way of printing x, printing the plot .show

# %% [markdown]
# To change the marker or line, you can put a third input argument into plot, which is a string that specifies the color and line style to be used in the plot. For example, *plot(x,y,'ro')* will plot the elements of x against the elements of y using red, r, circles, 'o'. The possible specifications are shown below in the table.
#
#
# | Symbol  | Description  | Symbol  |  Description |
# |:---:|:---:|:---:|:---:|
# |  b | blue  |  T |  T |
# |  g | green |  s | square  |
# |  r |  red |  d |  diamond |
# |  c |  cyan |  v | triangle (down)  |
# |  m |  magenta | ^  | triangle (up)   |
# |  y |  yellow | <  | triangle (left)   |
# |  k | black  |  > |  triangle (right)  |
# |  w |  white | p  | pentagon  |
# |  . |  point |  h |  hexagon |
# |  o |  circle | -  |  solid |
# |  x | x-mark  |  : |  dotted |
# |  + |  plus | -.  | dashdot  |
# |  * |  star |  --  | dashed  |
#
# **TRY IT!** Make a plot of the function $f(x) = x^2 for -5\le x \le 5$ using a dashed green line.

# %% [markdown]
# You can find a list with all the named colors that you can use in matplotlib here:
#
# https://matplotlib.org/3.1.0/gallery/color/named_colors.html
#
# and all linestyles here:
#
# https://matplotlib.org/3.1.0/gallery/lines_bars_and_markers/linestyles.html
#
# and marker styles here:
#
# https://matplotlib.org/1.4.1/api/markers_api.html

# %%
x = np.linspace(-5,5, 100) 
plt.plot(x, x**2, 'g--') #dashed line thats green
plt.show() # can do 'ro-.' after x**, to add a red circle line thats dashdotted

z = np.linspace(-5,5, 100) 
plt.plot(z, z**2, linestyle = '--', marker= 'd', markersize =15, color = 'blue') #another example
plt.show()

# %% [markdown]
# Before the *plt.show()* statement, you can add in and plot more datasets within one figure.
#
# **TRY IT!** Make a plot of the function $f(x) = x^2$ and  $g(x) = x^3$ for $ -5\le x \le 5$. Use different colors and markers for each function.

# %%
x = np.linspace(-5,5,20)
plt.plot(x, x**2, 'ko')
plt.plot(x, x**3, 'r*')
plt.plot(x, x**0.5, 'g>')
#plt.xlim(-2,2)
plt.show()
# Out:
# /var/folders/0b/8r746f051bv5nzsl3vqj95qm0000gn/T/ipykernel_80373/2746041238.py:4: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, x**0.5, 'g>')

# %% [markdown]
# It is customary in engineering and science to always give your plot a title and axis labels so that people know what your plot is about. Besides, sometimes you want to change the size of the figure as well. You can add a title to your plot using the *title* function, which takes as input a string and puts that string as the title of the plot. The functions *xlabel* and *ylabel* work in the same way to name your axis labels. For changing the size of the figure, we could create a figure object and resize it. Note, every time we call *plt.figure* function, we create a new figure object to draw something on it.
#
# **TRY IT!** Add a title and axis labels to the previous plot. And make the figure larger with width 10 inches, and height 6 inches.

# %%
plt.figure(figsize = (10,6))

x = np.linspace(-5,5,20)
plt.plot(x, x**.5, 'ko')
plt.plot(x, x**3, 'r*')
plt.title(f'Plot of Various Polynomials from {x[0]} to {x[-1]}')
plt.ylim(-2,2)
plt.xlabel('X axis', fontsize = 18)
plt.ylabel(r'Y axis with $\sqrt{x}$', fontsize = 18) #r says treat as raw string
plt.show()
# Out:
# /var/folders/0b/8r746f051bv5nzsl3vqj95qm0000gn/T/ipykernel_80373/1822198041.py:4: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, x**.5, 'ko')

# %% [markdown]
# We can see that we could change any part of the figure, such as the x and y axis label size by specify a *fontsize* argument in the *plt.xlabel* function. But there are some pre-defined styles that we could use to automatically change the style. Here is the list of the styles.

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# One of my favorite is the *seaborn* style, we could change it using the *plt.style.use* function, and let's see if we change it to 'seaborn-poster', it will make everything bigger.

# %%
plt.style.use('seaborn-v0_8-colorblind')

# %%
plt.figure(figsize = (10,6))

x = np.linspace(-5,5,20)
plt.plot(x, x**2, 'ko')
plt.plot(x, x**3, 'r*')
plt.title(f'Plot of Various Polynomials from {x[0]} to {x[-1]}')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %% [markdown]
# You can add a legend to your plot by using the *legend* function. And add a *label* argument in the *plot* function. The legend function also takes argument of *loc* to indicate where to put the legend, try to change it from 0 to 10.

# %% [markdown]
# Latec is a cloud style, for printers, use for scientific journals to publish, helps to write out equations
# we call to latec when we write our equations, python uses latec too

# %%
plt.figure(figsize = (10,6))

x = np.linspace(-5,5,20)
plt.plot(x, x**2, 'ko', label = r'$\alpha \cdot x^2$') #label, did raw string, alpha dot x sq
plt.plot(x, x**3, 'r*', label = r'$\beta \cdot x^3$')
plt.title(f'Plot of Various Polynomials from {x[0]} to {x[-1]}')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend(loc = 2)
plt.show()

# %% [markdown]
# #### You many have noticed the use of '\alpha' and '\beta' to indicate $\alpha$ and $\beta$ in the plot legend. This is Python using LaTeX to create math symbols. You can also use Latex in the axis names, plot title, etc.  For now, a couple useful things you many use (click on the box below to see how to write them using the '$' signs:
#
# \pi == π
#
# \delta == δ
#
# \Delta == Δ
#
# \Sigma == Σ
#
# \lesssim  ==  $\lesssim$
#
# \gtrsim == $ \gtrsim $
#
# X_{blabla} ==  $X_{blabla}$
#
# or if you want it in normal (not math/italic) font: X_\mathrm{blabla} == X$_\mathrm{blabla}$
#
# X^n == $X^n$

# %%
\pi == $\pi$
\delta == $\delta$
# Out:
#   Cell In[25], line 1
#     \pi == $\pi$
#      ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# Finally, you can further customize the appearance of your plot to change the limits of each axis using the *xlim* or *ylim* function. Also, you can use the *grid* function to turn on the grid of the figure.
#
# **TRY IT!** Change the limits of the plot so that x is visible from -6 to 6 and y is visible from -10 to 10. Turn the grid on.

# %%
x = np.arange(0,2*np.pi,0.1)
y = np.sin(x) #automatically in radians

plt.figure(figsize = (10,6))

x = np.linspace(-5,5,100)
plt.plot(x, x**2, 'ko', label = r'$\alpha \cdot x^2$',markersize = 4)
plt.plot(x, x**3, 'r*', label = r'$\beta \cdot x^3$')
plt.title(f'Plot of Various Polynomials from {x[0]} to {x[-1]}')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend(loc = 2)
plt.xlim(0,2*np.pi)
plt.ylim(0,15)
plt.grid()
plt.show()

# %% [markdown]
# We can create a table of plots on a single figure using the *subplot* function. The *subplot* function takes three inputs: the number of rows of plots, the number of columns of plots, and to which plot all calls to plotting functions should plot. You can move to a different subplot by calling the subplot again with a different entry for the plot location.
#
# There are several other plotting functions that plot x versus y data. Some of them are *scatter*, *bar*, *loglog*, *semilogx*, and *semilogy*. *scatter* works exactly the same as plot except it defaults to red circles (i.e., *plot(x,y,'ro')* is equivalent to *scatter(x,y)*). The *bar* function plots bars centered at x with height y. The *loglog*, *semilogx*, and *semilogy* functions plot the data in x and y with the x and y axis on a log scale, the x axis on a log scale and the y axis on a linear scale, and the y axis on a log scale and the x axis on a linear scale, respectively.
#
# **TRY IT!** Given the lists x = np.arange(11) and $y = x^2$, create a 2 by 3 subplot where each subplot plots x versus y using *plot*, *scatter*, *bar*, *loglog*, *semilogx*, and *semilogy*. Title and label each plot appropriately. Use a grid, but a legend is not necessary.

# %%
x = np.arange(11)
y = x**2

plt.figure(figsize = (14, 9))

plt.subplot(2, 3, 1) #2 rows 3 columns, 1 tells which plot it is
plt.plot(x,y,'r')
plt.title('Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

plt.subplot(2, 3, 2)
plt.scatter(x,y,)
plt.title('Scatter')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

plt.subplot(2, 3, 3)
plt.bar(x,y)
plt.title('Bar')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

plt.subplot(2, 3, 4)
plt.loglog(x,y,'g')
plt.title('Loglog')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(which='both')

plt.subplot(2, 3, 5)
plt.semilogx(x,y,'b')
plt.title('Semilogx')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(which='both')

plt.subplot(2, 3, 6)
plt.semilogy(x,y,'k')
plt.title('Semilogy')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

plt.tight_layout()

plt.show()

# %% [markdown]
# We could see that at the end of our plot, we used `plt.tight_layout` to make the sub-figures not overlap with each other, you can try and see the effect without this statement.
#
# Besides, sometimes, you want to save the figures as a specific format, such as pdf, jpeg, png, and so on. You can do this with the function `plt.savefig`.

# %% [markdown]
# Check your week 5 folder for the image file!

# %%
plt.figure(figsize = (8,6))
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.savefig('image.pdf') #you can also use any other filetype.

# %% [markdown]
# #### Check your saved figure in your folder!

# %% [markdown]
# Finally, there are other functions for plotting data in 2D. The `errorbar` function plots x versus y data but with error bars for each element. The `polar` function plots θ versus r rather than x versus y. The `stem` function plots stems at x with height at y. The `hist` function makes a histogram of a dataset; `boxplot` gives a statistical summary of a dataset; and `pie` makes a pie chart. The usage of these functions are left to your exploration. Do remember to check the examples on the [matplotlib gallery](https://matplotlib.org/gallery/index.html#gallery).

# %%
plt.figure( figsize = (5, 5 ) )
plt.plot  ( x, y, color = 'red', linestyle = '--' ) 
plt.xlabel( 't'                 , fontsize = 20 )
plt.ylabel( 'Sin[ 2 $\pi$ t ] ' , fontsize = 20 )
plt.xlim( 0, 20 )

#add a title on the plot and make sure it has big enough font

plt.title('My sin function', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'My sin function')

# %% [markdown]
# ### Practice:
#
# - Make a plot showing one full period of $\sin(ax)$.
# - Choose $a$ so that the period is 1.
# - Show only two periods on the plot.
# - Label the axes.
# - Title your plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
a = 2*np.pi
x = np.arange(0,3.0001,0.0001) #3 periods 
y = np.sin(a*x)
plt.plot(x,y)
plt.title ( "My Sine" ) # already has plot named my sine so had to restart kernal and run
plt.xlabel("$x$")
plt.ylabel(r"$\sin{a\cdot x}$") # r in front helps to interpret the latec in $$
plt.xlim(0,2) # now only shows 2 periods
# Out:
# (0.0, 2.0)

# %% [markdown]
# ### Formating ticks
# To fix the labeling on your x and y axis to what you want it to show use:
#
# `     plt.yticks($<yourticks>$)`
#
# (same for xticks).
#
# For example:
# `    plt.yticks(np.arange(-1.0, 1.2, step = 0.2 ))`
#
# `    plt.xticks(np.arange( 10, 11.1, 0.2 ))`

# %%
plt.figure( figsize = (10, 5 ) )
plt.plot  ( x, y,  color = 'red' , linestyle = '--', linewidth = 2) 
plt.xlabel( 't'                 , fontsize = 20 )
plt.ylabel( 'Sin[ 2 $\pi$ t ] ' , fontsize = 20 )
plt.title( ' My plot' , fontsize = 20 )
plt.yticks( fontsize = 20 )
plt.xticks( fontsize = 20, rotation = 45 )
plt.xlim( 0,  2  )
plt.ylim( -1.2 , 1.2 )

plt.yticks([-1,0,0.5,1]  )  # gives a list of each specific mark
plt.xticks( np.arange( 0, 2, 0.4 ) ) # goes from 0 to 2 with a step of .4
#access and change the tick parameters for this plot:
plt.tick_params(axis='both',which='major',length=18, width=1,direction='in')

#plt.tick_params(axis='both',which='minor',length=8, width=3,direction='in')

#### to change the border lines you can change the (global) rc parameters of your system:
plt.rc('axes', linewidth = 2 )
plt.show()

# %% [markdown]
# ### Practice:
# Let’s read in our first data using numpy loadtxt and plot them. Open 'HST_infrared_spectra.dat' with loadtxt .

# %%
data_hst = np.loadtxt('HST_infrared_spectra.dat') # if in same folder ie in folder week 5 lecture notes can just call as string
print(np.shape(data_hst)) # it is (144,3), 2 d array
#data_hst = np.genfromtxt('HST_infrared_spectra.dat')  another way to load file
# Out:
# (144, 3)

# %% [markdown]
# ### Try plotting it!

# %%
plt.figure( figsize= (10, 4))

plt.plot(data_hst[ :, 0 ], data_hst[ :, 1],'*-',markersize = 7,linewidth = 1,\ #all of it, column zero, all values of i, zero values of j
         color= 'magenta', label = "Obs. 1")
plt.plot(data_hst[ :, 0 ], data_hst[ :, 2],'d-',markersize = 7,linewidth = 1,\ # (rows, columns)
         color= 'forestgreen',label = "Obs. 2")
plt.xlabel(r'wavelength $\mu$m')
plt.ylabel('flux')
plt.grid()
plt.legend()
plt.show()
# Out:
#   Cell In[6], line 3
#     plt.plot(data_hst[ :, 0 ], data_hst[ :, 1],'*-',markersize = 7,linewidth = 1,\ #all of it, column zero, all values of i, zero values of j
#                                                                                   ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# Remember that you can also use `np.genfromtxt()` to read in the data; let's try it:

# %%
#data_2 = np.genfromtxt( "first_data_read_plot.dat", comments = "#" )

# %%
#print your data; print the first 5 lines for all columns:

# %%
# and data_2; print the last 5 columns:

# %%
##let's make our life easier by assigning the data/ columns to variables:

# %%
# let's plot it:

# %%
# let's make it log-y version:

# %% [markdown]
# ### Practice:
# - Let’s draw a bunch of random samples from a Gaussian or Normal distribution:
# - (probability density function for normal distribution)
# - $\frac{1}{\sqrt{2\pi\sigma^2}}e^{\frac(x-\mu)^2}{2\sigma^2}$
# - Start by drawing only 100 points
# - Plot a histogram.
# - Then increase to 1,000 and 10,000 and plot histograms.

# %%
mu , sigma = 0, 0.1 # mean and standard deviation of a Gaussian distribution
mu = 0  #this is a normal way to assignvariables
sigma = 0.1 #you can do it in one string as seen in line 1 above 
s = np.random.normal(mu, sigma, 1000)  # test different values here  100; 1000; 10000 

plt.figure( figsize = (10, 4) )

plt.hist(s, 100, density = True, facecolor = 'k', alpha = 0.75 ) #s is array of numbers, 100 is bins
plt.xlabel( 'Bins'                            , fontsize = 12 )
plt.ylabel( 'Frequency'            , fontsize = 12 )
plt.title( 'Histogram of Gaussian probability', fontsize = 12 )
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ## Now let’s turn interactive plotting on. In Jupyter type:
#
# `%matplotlib` This calls a magic function so that the plot is no longer contained in the notebook.
#
# To run this inside a .py script you need to use `plt.ion()`.
#
# To turn them off later use:
#
# `%matplotlib inline` and `plt.ioff()`respectively.

# %%
# %matplotlib inline

# %% [markdown]
# ### Practice:
#
# - Let's use Numpy's psuedo-random number generator to make a scatter plot of points with random x and y coordinates.
# - ...but your data has extra layers of information! the color of each point and its size (could be e.g., color corresponds to % of test in given measurement bin and size to error bar of measurement or..... )
# - So let's plot the points with different sizes and colors.

# %%
N = 500
x = np.random.rand(N)
y = np.random.rand(N)
area = (40 * np.random.rand(N))**2  # 0 to 15 point radii

# %%
colors = ['red','orange','yellow','green','blue']*100
plt.figure ( figsize = ( 10, 10 ) )
plt.scatter( x, y, c = colors , s = area, alpha=0.5 ) #feeds in array of colors and sizes, if just (x,y) plain dots 1 color 1 size
plt.xticks ( size = 30)
plt.yticks ( size = 30)
plt.show()

# %% [markdown]
# ### Displaying Images
# - Find the file 'jup_hst_nasa.png' in your folder.
# - Next import the image tool from matplotlib.

# %%
import matplotlib.image as mpimg

# %%
##read the image in as an n x m x 3 array for color (r,g,b) images.
img = mpimg.imread( 'jup_hst_nasa.png' ) #imread reads in 
print(np.shape(img)) #3 is red, green, blue
# Out:
# (1400, 1400, 3)

# %%
##or just show it directly:
plt.figure(figsize = (5,5))
imgplot = plt.imshow(img)
plt.show()

# %%
##now plot:
plt.figure(figsize = (5,5))
limg = img[ :, :, 1]
imgplot = plt.imshow( limg, cmap = 'RdYlBu' )
plt.colorbar()
plt.show()

# %% [markdown]
# For a tutorial on other manipulations of an image see: https://matplotlib.org/3.1.1/tutorials/introductory/images.html#sphx-glr-tutorials-introductory-images-py

# %% [markdown]
# ## Text Annotations

# %% [markdown]
# Let's add some text to our good old sine plot:

# %%
x = np.arange(0,20.01,.01)
y = np.sin(2*np.pi*x) #period of 1
plt.figure( figsize = (10, 5 ) )
plt.plot  ( x, y,color = 'red',linewidth = 4,  linestyle = '--' ) 

plt.xlabel( 't'                 ) 
plt.ylabel( 'Sin[ 2 $\pi$ t ] ' )
plt.title( ' My first sin plot' )

plt.xlim( 0,2 )
plt.ylim(-1.5,1.5)

plt.tick_params(axis='both',which='major',length=12, width=4,direction='out')

#add text:
plt.text( 0.2 , 1.1, 'Peak',fontsize = 14 ) #to add text !!!!!!!, 0.2 and 1.1 are coordinates in data we are using

# add arrow annotation:
plt. annotate( 'trough', xy=(1.75, -.9 ), xytext=( 1.8 , .6),
            arrowprops=dict(facecolor='black', shrink=0.05),
            fontsize = 14) 

plt.text(
    0.9, 0, "  Slope  ", ha = "center", va = "center", rotation = 63, size = 15,
    bbox = dict(boxstyle="darrow,pad=0.2", fc="cyan", ec = "b", lw = 1) ) #horizontial allignment, bbox is make an arrow box

plt.show()
